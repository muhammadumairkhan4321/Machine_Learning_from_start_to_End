# %% [markdown]
# # **23 June 2026**

# %% [markdown]
# ### **Our First Python Program**

# %%
print("Hello! World")
# Out:
# Hello! World

# %%
# backslash + n lekiny sy next line start hota hai
print("Hello! Umair \nWelcome")
# Out:
# Hello! Umair
# Welcome
